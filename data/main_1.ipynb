# %%
import pandas as pd

# %%
df = pd.read_csv('air_quality_all_districts.csv')
df.drop(['PM10'], axis=1, inplace=True)
df
# Out:
#        District           Local Time                   UTC Time   City  \
# 0       Ba Dinh  2022-01-01 07:00:00  2022-01-01T00:00:00+00:00  Hanoi
# 1       Ba Dinh  2022-01-01 08:00:00  2022-01-01T01:00:00+00:00  Hanoi
# 2       Ba Dinh  2022-01-01 09:00:00  2022-01-01T02:00:00+00:00  Hanoi
# 3       Ba Dinh  2022-01-01 10:00:00  2022-01-01T03:00:00+00:00  Hanoi
# 4       Ba Dinh  2022-01-01 11:00:00  2022-01-01T04:00:00+00:00  Hanoi
# ...         ...                  ...                        ...    ...
# 310171  Ha Dong  2025-01-01 02:00:00  2024-12-31T19:00:00+00:00  Hanoi
# 310172  Ha Dong  2025-01-01 03:00:00  2024-12-31T20:00:00+00:00  Hanoi
# 310173  Ha Dong  2025-01-01 04:00:00  2024-12-31T21:00:00+00:00  Hanoi
# 310174  Ha Dong  2025-01-01 05:00:00  2024-12-31T22:00:00+00:00  Hanoi
# 310175  Ha Dong  2025-01-01 06:00:00  2024-12-31T23:00:00+00:00  Hanoi
#
#        Country Code          Timezone       CO    NO2     O3    PM25    SO2  \
# ...

# %%
df.to_csv('data.csv', index=False)
print('Done')
# Out:
# Done
